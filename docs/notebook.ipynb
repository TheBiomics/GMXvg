# %% [markdown]
# # 🧬 GMXvg Interactive Tutorial
#
# Welcome to the GMXvg interactive tutorial! This notebook will guide you through analyzing molecular dynamics data step by step.
#
# **What you'll learn:**
# - How to load and plot .xvg files
# - How to create publication-ready figures
#
# **No prior experience needed!** Just follow along and run each cell.

# %%
# Let's start by running existing examples

# In case GMXvg not installed
from UtilityLib import SYS, OS, EntityPath, ObjDict
SYS.path.append(OS.path.expanduser("~/Git-Projects/GMXvg"))

# Import GMXvg
try:
  import gmxvg
  print("✅ GMXvg imported successfully!")
except ImportError as e:
  print(f"❌ GMXvg not found. Install with: pip install gmxvg {e}")
# Create our plotter
plotter = gmxvg.GMXvg(path_base=EntityPath(gmxvg.__file__).parent(1) / 'docs/example-xvgs')
print("🚀 Ready to plot molecular dynamics XVG files!")
plotter.path_base
plotter.plot_cli()

# %%
# Cleanup generated images
plotter.flag_cleanup = 'yes'
plotter._cleanup_working_dir()
